# %%
import numpy as np
from sklearn import preprocessing

raw_csv_data = np.loadtxt('Audiobooks-data.csv',delimiter = ',')
unscaled_inputs_all = raw_csv_data[:,1:-1]
targets_all = raw_csv_data[:,-1]

# %%
#バランシング(targetが0と1の量が揃うように調整、具体的には0の数が1の数を超えたらそれ以降の0のデータを全て消す。)
num_one_targets = int(np.sum(targets_all))
zero_targets_counter = 0
indices_to_remove = []

for i in range(targets_all.shape[0]):
    if targets_all[i]==0:
        zero_targets_counter += 1
        if zero_targets_counter > num_one_targets:
            indices_to_remove.append(i)
            
unscaled_inputs_equal_priors = np.delete(unscaled_inputs_all,indices_to_remove,axis = 0)
targets_equal_priors = np.delete(targets_all,indices_to_remove,axis = 0)

# %%
#標準化(データの影響の大きさを同じにする)
scaled_inputs = preprocessing.scale(unscaled_inputs_equal_priors)

# %%
#シャッフル(バッチ処理をするため、処理ごとに特定のデータが集中してしまうことを避ける。)
shuffled_indices = np.arange(scaled_inputs.shape[0])
np.random.shuffle(shuffled_indices)
shuffled_inputs = scaled_inputs[shuffled_indices]
shuffled_targets = targets_equal_priors[shuffled_indices]

# %%
#訓練用、検証用、テスト用に分割_count
samples_count = shuffled_inputs.shape[0]
train_samples_count = int(0.8*samples_count)
validation_samples_count = int(0.1*samples_count)
test_samples_count = samples_count -train_samples_count - validation_samples_count

train_inputs = shuffled_inputs[:train_samples_count]
train_targets = shuffled_targets[:train_samples_count]

validation_inputs = shuffled_inputs[train_samples_count:train_samples_count+validation_samples_count]
validation_targets = shuffled_targets[train_samples_count:train_samples_count+validation_samples_count]

test_inputs = shuffled_inputs[train_samples_count+validation_samples_count:]
test_targets = shuffled_targets[train_samples_count+validation_samples_count:]
#大体0と1が半々になっていると良い。
print(np.sum(train_targets),train_samples_count,np.sum(train_targets)/train_samples_count)
print(np.sum(validation_targets),train_samples_count,np.sum(validation_targets)/validation_samples_count)
print(np.sum(test_targets),test_samples_count,np.sum(test_targets)/test_samples_count)
# Out:
# 1798.0 3579 0.502374965074043
# 226.0 3579 0.5055928411633109
# 213.0 448 0.47544642857142855

# %%
#データ保存
np.savez('Audiobooks_data_train',inputs = train_inputs,targets = train_targets)
np.savez('Audiobooks_data_validation',inputs = validation_inputs,targets = validation_targets)
np.savez('Audiobooks_data_test',inputs = test_inputs,targets = test_targets)

# %%
import tensorflow as tf

input_size = 10
output_size = 2
# 隠れ層のユニットの数を定義します
hidden_layer_size = 50
    
# モデルの定義を進めていきます
model = tf.keras.Sequential([    
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 1番目の隠れ層
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 2番目の隠れ層
    tf.keras.layers.Dense(output_size, activation='softmax') # 出力層
])
#損失が上がったり下がったりしているのでアーリーストッピングが必要
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics = ['accuracy'])
batch_size = 100
max_epochs = 100
model.fit(train_inputs,
          train_targets,
          batch_size = batch_size,
          epochs =max_epochs,
          validation_data = (validation_inputs,validation_targets),
          verbose = 2)
# Out:
# Epoch 1/100
# 36/36 - 1s - loss: 0.5901 - accuracy: 0.6795 - val_loss: 0.5070 - val_accuracy: 0.7584
# Epoch 2/100
# 36/36 - 0s - loss: 0.4736 - accuracy: 0.7583 - val_loss: 0.4335 - val_accuracy: 0.7919
# Epoch 3/100
# 36/36 - 0s - loss: 0.4206 - accuracy: 0.7874 - val_loss: 0.3999 - val_accuracy: 0.8054
# Epoch 4/100
# 36/36 - 0s - loss: 0.3942 - accuracy: 0.7932 - val_loss: 0.3826 - val_accuracy: 0.7919
# Epoch 5/100
# 36/36 - 0s - loss: 0.3776 - accuracy: 0.7972 - val_loss: 0.3701 - val_accuracy: 0.8098
# Epoch 6/100
# 36/36 - 0s - loss: 0.3663 - accuracy: 0.8100 - val_loss: 0.3632 - val_accuracy: 0.8121
# Epoch 7/100
# 36/36 - 0s - loss: 0.3589 - accuracy: 0.8122 - val_loss: 0.3592 - val_accuracy: 0.7919
# Epoch 8/100
# 36/36 - 0s - loss: 0.3532 - accuracy: 0.8125 - val_loss: 0.3470 - val_accuracy: 0.8166
# Epoch 9/100
# 36/36 - 0s - loss: 0.3484 - accuracy: 0.8134 - val_loss: 0.3471 - val_accuracy: 0.8210
# Epoch 10/100
# 36/36 - 0s - loss: 0.3453 - accuracy: 0.8097 - val_loss: 0.3435 - val_accuracy: 0.8031
# Epoch 11/100
# 36/36 - 0s - loss: 0.3415 - accuracy: 0.8170 - val_loss: 0.3375 - val_accuracy: 0.7987
# Epoch 12/100
# 36/36 - 0s - loss: 0.3421 - accuracy: 0.8153 - val_loss: 0.3393 - val_accuracy: 0.8277
# Epoch 13/100
# 36/36 - 0s - loss: 0.3373 - accuracy: 0.8220 - val_loss: 0.3389 - val_accuracy: 0.8076
# Epoch 14/100
# 36/36 - 0s - loss: 0.3348 - accuracy: 0.8136 - val_loss: 0.3363 - val_accuracy: 0.8121
# Epoch 15/100
# 36/36 - 0s - loss: 0.3357 - accuracy: 0.8170 - val_loss: 0.3307 - val_accuracy: 0.8121
# Epoch 16/100
# 36/36 - 0s - loss: 0.3297 - accuracy: 0.8284 - val_loss: 0.3360 - val_accuracy: 0.8143
# Epoch 17/100
# 36/36 - 0s - loss: 0.3283 - accuracy: 0.8234 - val_loss: 0.3341 - val_accuracy: 0.8009
# Epoch 18/100
# 36/36 - 0s - loss: 0.3281 - accuracy: 0.8229 - val_loss: 0.3317 - val_accuracy: 0.8210
# Epoch 19/100
# 36/36 - 0s - loss: 0.3264 - accuracy: 0.8226 - val_loss: 0.3274 - val_accuracy: 0.8166
# Epoch 20/100
# 36/36 - 0s - loss: 0.3255 - accuracy: 0.8209 - val_loss: 0.3323 - val_accuracy: 0.8188
# Epoch 21/100
# 36/36 - 0s - loss: 0.3246 - accuracy: 0.8248 - val_loss: 0.3253 - val_accuracy: 0.8210
# Epoch 22/100
# 36/36 - 0s - loss: 0.3250 - accuracy: 0.8189 - val_loss: 0.3293 - val_accuracy: 0.8255
# Epoch 23/100
# 36/36 - 0s - loss: 0.3277 - accuracy: 0.8223 - val_loss: 0.3256 - val_accuracy: 0.8098
# Epoch 24/100
# 36/36 - 0s - loss: 0.3225 - accuracy: 0.8226 - val_loss: 0.3226 - val_accuracy: 0.8210
# Epoch 25/100
# 36/36 - 0s - loss: 0.3213 - accuracy: 0.8287 - val_loss: 0.3285 - val_accuracy: 0.8210
# Epoch 26/100
# 36/36 - 0s - loss: 0.3194 - accuracy: 0.8251 - val_loss: 0.3261 - val_accuracy: 0.8143
# Epoch 27/100
# 36/36 - 0s - loss: 0.3221 - accuracy: 0.8243 - val_loss: 0.3233 - val_accuracy: 0.8166
# Epoch 28/100
# 36/36 - 0s - loss: 0.3236 - accuracy: 0.8192 - val_loss: 0.3324 - val_accuracy: 0.8143
# Epoch 29/100
# 36/36 - 0s - loss: 0.3202 - accuracy: 0.8234 - val_loss: 0.3256 - val_accuracy: 0.8076
# Epoch 30/100
# 36/36 - 0s - loss: 0.3140 - accuracy: 0.8310 - val_loss: 0.3193 - val_accuracy: 0.8255
# Epoch 31/100
# 36/36 - 0s - loss: 0.3188 - accuracy: 0.8268 - val_loss: 0.3225 - val_accuracy: 0.8076
# Epoch 32/100
# 36/36 - 0s - loss: 0.3188 - accuracy: 0.8301 - val_loss: 0.3238 - val_accuracy: 0.8255
# Epoch 33/100
# 36/36 - 0s - loss: 0.3156 - accuracy: 0.8312 - val_loss: 0.3294 - val_accuracy: 0.8255
# Epoch 34/100
# 36/36 - 0s - loss: 0.3150 - accuracy: 0.8293 - val_loss: 0.3264 - val_accuracy: 0.8300
# Epoch 35/100
# 36/36 - 0s - loss: 0.3209 - accuracy: 0.8231 - val_loss: 0.3217 - val_accuracy: 0.8233
# Epoch 36/100
# 36/36 - 0s - loss: 0.3159 - accuracy: 0.8279 - val_loss: 0.3242 - val_accuracy: 0.8121
# Epoch 37/100
# 36/36 - 0s - loss: 0.3141 - accuracy: 0.8270 - val_loss: 0.3269 - val_accuracy: 0.8121
# Epoch 38/100
# 36/36 - 0s - loss: 0.3144 - accuracy: 0.8284 - val_loss: 0.3187 - val_accuracy: 0.8233
# Epoch 39/100
# 36/36 - 0s - loss: 0.3164 - accuracy: 0.8254 - val_loss: 0.3294 - val_accuracy: 0.8076
# Epoch 40/100
# 36/36 - 0s - loss: 0.3125 - accuracy: 0.8312 - val_loss: 0.3186 - val_accuracy: 0.8166
# Epoch 41/100
# 36/36 - 0s - loss: 0.3120 - accuracy: 0.8298 - val_loss: 0.3215 - val_accuracy: 0.8166
# Epoch 42/100
# 36/36 - 0s - loss: 0.3138 - accuracy: 0.8287 - val_loss: 0.3267 - val_accuracy: 0.8233
# Epoch 43/100
# 36/36 - 0s - loss: 0.3130 - accuracy: 0.8307 - val_loss: 0.3192 - val_accuracy: 0.8098
# Epoch 44/100
# 36/36 - 0s - loss: 0.3125 - accuracy: 0.8290 - val_loss: 0.3183 - val_accuracy: 0.8255
# Epoch 45/100
# 36/36 - 0s - loss: 0.3096 - accuracy: 0.8326 - val_loss: 0.3173 - val_accuracy: 0.8300
# Epoch 46/100
# 36/36 - 0s - loss: 0.3143 - accuracy: 0.8276 - val_loss: 0.3193 - val_accuracy: 0.8143
# Epoch 47/100
# 36/36 - 0s - loss: 0.3137 - accuracy: 0.8321 - val_loss: 0.3152 - val_accuracy: 0.8345
# Epoch 48/100
# 36/36 - 0s - loss: 0.3123 - accuracy: 0.8324 - val_loss: 0.3308 - val_accuracy: 0.8098
# Epoch 49/100
# 36/36 - 0s - loss: 0.3120 - accuracy: 0.8290 - val_loss: 0.3217 - val_accuracy: 0.8143
# Epoch 50/100
# 36/36 - 0s - loss: 0.3134 - accuracy: 0.8312 - val_loss: 0.3257 - val_accuracy: 0.8031
# Epoch 51/100
# 36/36 - 0s - loss: 0.3231 - accuracy: 0.8159 - val_loss: 0.3218 - val_accuracy: 0.8121
# Epoch 52/100
# 36/36 - 0s - loss: 0.3107 - accuracy: 0.8332 - val_loss: 0.3352 - val_accuracy: 0.8188
# Epoch 53/100
# 36/36 - 0s - loss: 0.3165 - accuracy: 0.8237 - val_loss: 0.3170 - val_accuracy: 0.8121
# Epoch 54/100
# 36/36 - 0s - loss: 0.3099 - accuracy: 0.8351 - val_loss: 0.3204 - val_accuracy: 0.8076
# Epoch 55/100
# 36/36 - 0s - loss: 0.3088 - accuracy: 0.8284 - val_loss: 0.3145 - val_accuracy: 0.8188
# Epoch 56/100
# 36/36 - 0s - loss: 0.3102 - accuracy: 0.8318 - val_loss: 0.3219 - val_accuracy: 0.8188
# Epoch 57/100
# 36/36 - 0s - loss: 0.3092 - accuracy: 0.8329 - val_loss: 0.3435 - val_accuracy: 0.7964
# Epoch 58/100
# 36/36 - 0s - loss: 0.3118 - accuracy: 0.8301 - val_loss: 0.3133 - val_accuracy: 0.8255
# Epoch 59/100
# 36/36 - 0s - loss: 0.3091 - accuracy: 0.8318 - val_loss: 0.3126 - val_accuracy: 0.8121
# Epoch 60/100
# 36/36 - 0s - loss: 0.3076 - accuracy: 0.8338 - val_loss: 0.3194 - val_accuracy: 0.8121
# Epoch 61/100
# 36/36 - 0s - loss: 0.3111 - accuracy: 0.8321 - val_loss: 0.3323 - val_accuracy: 0.8009
# Epoch 62/100
# 36/36 - 0s - loss: 0.3099 - accuracy: 0.8268 - val_loss: 0.3234 - val_accuracy: 0.8054
# Epoch 63/100
# 36/36 - 0s - loss: 0.3133 - accuracy: 0.8248 - val_loss: 0.3373 - val_accuracy: 0.8166
# Epoch 64/100
# 36/36 - 0s - loss: 0.3138 - accuracy: 0.8293 - val_loss: 0.3244 - val_accuracy: 0.8098
# Epoch 65/100
# 36/36 - 0s - loss: 0.3093 - accuracy: 0.8351 - val_loss: 0.3182 - val_accuracy: 0.8076
# Epoch 66/100
# 36/36 - 0s - loss: 0.3082 - accuracy: 0.8321 - val_loss: 0.3197 - val_accuracy: 0.8098
# Epoch 67/100
# 36/36 - 0s - loss: 0.3132 - accuracy: 0.8332 - val_loss: 0.3195 - val_accuracy: 0.8210
# Epoch 68/100
# 36/36 - 0s - loss: 0.3075 - accuracy: 0.8315 - val_loss: 0.3167 - val_accuracy: 0.8009
# Epoch 69/100
# 36/36 - 0s - loss: 0.3075 - accuracy: 0.8310 - val_loss: 0.3154 - val_accuracy: 0.8210
# Epoch 70/100
# 36/36 - 0s - loss: 0.3088 - accuracy: 0.8287 - val_loss: 0.3148 - val_accuracy: 0.8233
# Epoch 71/100
# 36/36 - 0s - loss: 0.3122 - accuracy: 0.8307 - val_loss: 0.3199 - val_accuracy: 0.8166
# Epoch 72/100
# 36/36 - 0s - loss: 0.3089 - accuracy: 0.8315 - val_loss: 0.3152 - val_accuracy: 0.8054
# Epoch 73/100
# 36/36 - 0s - loss: 0.3084 - accuracy: 0.8315 - val_loss: 0.3194 - val_accuracy: 0.8143
# Epoch 74/100
# 36/36 - 0s - loss: 0.3101 - accuracy: 0.8262 - val_loss: 0.3203 - val_accuracy: 0.7987
# Epoch 75/100
# 36/36 - 0s - loss: 0.3096 - accuracy: 0.8318 - val_loss: 0.3168 - val_accuracy: 0.8166
# Epoch 76/100
# 36/36 - 0s - loss: 0.3076 - accuracy: 0.8332 - val_loss: 0.3157 - val_accuracy: 0.8210
# Epoch 77/100
# 36/36 - 0s - loss: 0.3069 - accuracy: 0.8340 - val_loss: 0.3207 - val_accuracy: 0.7964
# Epoch 78/100
# 36/36 - 0s - loss: 0.3061 - accuracy: 0.8324 - val_loss: 0.3221 - val_accuracy: 0.7987
# Epoch 79/100
# 36/36 - 0s - loss: 0.3103 - accuracy: 0.8265 - val_loss: 0.3227 - val_accuracy: 0.8143
# Epoch 80/100
# 36/36 - 0s - loss: 0.3056 - accuracy: 0.8321 - val_loss: 0.3142 - val_accuracy: 0.8121
# Epoch 81/100
# 36/36 - 0s - loss: 0.3070 - accuracy: 0.8382 - val_loss: 0.3300 - val_accuracy: 0.8121
# Epoch 82/100
# 36/36 - 0s - loss: 0.3100 - accuracy: 0.8310 - val_loss: 0.3137 - val_accuracy: 0.8121
# Epoch 83/100
# 36/36 - 0s - loss: 0.3065 - accuracy: 0.8298 - val_loss: 0.3160 - val_accuracy: 0.8188
# Epoch 84/100
# 36/36 - 0s - loss: 0.3065 - accuracy: 0.8326 - val_loss: 0.3274 - val_accuracy: 0.8076
# Epoch 85/100
# 36/36 - 0s - loss: 0.3069 - accuracy: 0.8343 - val_loss: 0.3109 - val_accuracy: 0.8255
# Epoch 86/100
# 36/36 - 0s - loss: 0.3069 - accuracy: 0.8329 - val_loss: 0.3187 - val_accuracy: 0.7987
# Epoch 87/100
# 36/36 - 0s - loss: 0.3061 - accuracy: 0.8312 - val_loss: 0.3258 - val_accuracy: 0.8054
# Epoch 88/100
# 36/36 - 0s - loss: 0.3047 - accuracy: 0.8351 - val_loss: 0.3202 - val_accuracy: 0.8143
# Epoch 89/100
# 36/36 - 0s - loss: 0.3072 - accuracy: 0.8332 - val_loss: 0.3201 - val_accuracy: 0.8143
# Epoch 90/100
# 36/36 - 0s - loss: 0.3056 - accuracy: 0.8329 - val_loss: 0.3211 - val_accuracy: 0.8121
# Epoch 91/100
# 36/36 - 0s - loss: 0.3052 - accuracy: 0.8340 - val_loss: 0.3210 - val_accuracy: 0.8143
# Epoch 92/100
# 36/36 - 0s - loss: 0.3084 - accuracy: 0.8273 - val_loss: 0.3177 - val_accuracy: 0.8166
# Epoch 93/100
# 36/36 - 0s - loss: 0.3093 - accuracy: 0.8310 - val_loss: 0.3155 - val_accuracy: 0.8098
# Epoch 94/100
# 36/36 - 0s - loss: 0.3095 - accuracy: 0.8270 - val_loss: 0.3198 - val_accuracy: 0.8233
# Epoch 95/100
# 36/36 - 0s - loss: 0.3068 - accuracy: 0.8377 - val_loss: 0.3146 - val_accuracy: 0.8188
# Epoch 96/100
# 36/36 - 0s - loss: 0.3075 - accuracy: 0.8304 - val_loss: 0.3134 - val_accuracy: 0.8121
# Epoch 97/100
# 36/36 - 0s - loss: 0.3045 - accuracy: 0.8307 - val_loss: 0.3194 - val_accuracy: 0.8233
# Epoch 98/100
# 36/36 - 0s - loss: 0.3037 - accuracy: 0.8371 - val_loss: 0.3144 - val_accuracy: 0.7964
# Epoch 99/100
# 36/36 - 0s - loss: 0.3042 - accuracy: 0.8365 - val_loss: 0.3195 - val_accuracy: 0.8233
# Epoch 100/100
# 36/36 - 0s - loss: 0.3092 - accuracy: 0.8276 - val_loss: 0.3129 - val_accuracy: 0.8166
